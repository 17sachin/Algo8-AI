# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Top_Movies")

# %% [markdown]
# # Basic Analysis of Data

# %%
df.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
df.shape
# Out:
# (100, 62)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
df.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %% [markdown]
# # Data Analysis - Subtask 1:

# %%
df["Gross"]=df["Gross"].floordiv(1000000)
df["budget"]=df["budget"].floordiv(1000000)

# %%
df
# Out:
#                                            Title  title_year  budget  Gross  \
# 0                                     La La Land        2016      30    151
# 1                                       Zootopia        2016     150    341
# 2                                           Lion        2016      12     51
# 3                                        Arrival        2016      47    100
# 4                          Manchester by the Sea        2016       9     47
# ..                                           ...         ...     ...    ...
# 95                                      Whiplash        2014       3     13
# 96                               Before Midnight        2013       3      8
# 97    Star Wars: Episode VII - The Force Awakens        2015     245    936
# 98  Harry Potter and the Deathly Hallows: Part I        2010     150    296
# 99                       Tucker and Dale vs Evil        2010       5      0
#
# ...

# %% [markdown]
# # Subtask 2:

# %%
df["Profit"]=df["Gross"]-df["budget"]

# %%
df
# Out:
#                                            Title  title_year  budget  Gross  \
# 0                                     La La Land        2016      30    151
# 1                                       Zootopia        2016     150    341
# 2                                           Lion        2016      12     51
# 3                                        Arrival        2016      47    100
# 4                          Manchester by the Sea        2016       9     47
# ..                                           ...         ...     ...    ...
# 95                                      Whiplash        2014       3     13
# 96                               Before Midnight        2013       3      8
# 97    Star Wars: Episode VII - The Force Awakens        2015     245    936
# 98  Harry Potter and the Deathly Hallows: Part I        2010     150    296
# 99                       Tucker and Dale vs Evil        2010       5      0
#
# ...

# %%
df.sort_values(by=["Profit"],ascending=False , inplace=True , ignore_index=True)

# %%
top_10=df.loc[0:9,"Title"]

# %%
top_10
# Out:
# 0    Star Wars: Episode VII - The Force Awakens
# 1                                  The Avengers
# 2                                      Deadpool
# 3               The Hunger Games: Catching Fire
# 4                                   Toy Story 3
# 5                         The Dark Knight Rises
# 6                                The Lego Movie
# 7                                      Zootopia
# 8                                 Despicable Me
# 9                                    Inside Out
# Name: Title, dtype: object

# %% [raw]
# Plot a scatter or a combined plot between the columns budget and profit, and then write a few lines about what you saw.

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='budget',y='Profit', data=df)
plt.title("Scatter plot of budget and Profit")
# Out:
# Text(0.5, 1.0, 'Scatter plot of budget and Profit')

# %% [raw]
# Analysis from the scatter plot is as follows:
#     Budget vs Profit data is right skewed.
#     A very few postive trend between budget and profit as budget increases the profit also increases.
#     There are also movies having high budget but profit is in negative
#     Movies having budget from 0 to 100 mln shows maximum movies giving profit.

# %% [raw]
# Extract the movies having a loss and save them in a new dataframe called neg profit

# %%
neg_profit=df[df['Profit'] < 0]

# %%
neg_profit
# Out:
#                           Title  title_year  budget  Gross  \
# 89      Tucker and Dale vs Evil        2010       5      0
# 90                        Amour        2012       8      0
# 91                         Rush        2013      38     26
# 92                      Warrior        2011      25     13
# 93                      Flipped        2010      14      1
# 94           X-Men: First Class        2011     160    146
# 95  Scott Pilgrim vs. the World        2010      60     31
# 96                      Tangled        2010     260    200
# 97             Edge of Tomorrow        2014     178    100
# 98            The Little Prince        2015      81      1
# 99                         Hugo        2011     170     73
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 89       Katrina Bowden        Tyler Labine          Chelan Simmons
# 90     Isabelle Huppert     Emmanuelle Riva  Jean-Louis Trintignant
# ...

# %% [markdown]
# # Subtask 3

# %%
df["Popularity"]=df['actor_1_facebook_likes']+df['actor_2_facebook_likes']+df['actor_3_facebook_likes']

# %%
df
# Out:
#                                          Title  title_year  budget  Gross  \
# 0   Star Wars: Episode VII - The Force Awakens        2015     245    936
# 1                                 The Avengers        2012     220    623
# 2                                     Deadpool        2016      58    363
# 3              The Hunger Games: Catching Fire        2013     130    424
# 4                                  Toy Story 3        2010     200    414
# ..                                         ...         ...     ...    ...
# 95                 Scott Pilgrim vs. the World        2010      60     31
# 96                                     Tangled        2010     260    200
# 97                            Edge of Tomorrow        2014     178    100
# 98                           The Little Prince        2015      81      1
# 99                                        Hugo        2011     170     73
#
#            actor_1_name       actor_2_name           actor_3_name  \
# ...

# %%
top_popular_actors=df.sort_values(by=["Popularity"],ascending=False , inplace=True , ignore_index=True)

# %%
top_5=df.loc[0:4,"Popularity"]

# %%
top_5
# Out:
# 0    138800.0
# 1     79000.0
# 2     76000.0
# 3     74818.0
# 4     73000.0
# Name: Popularity, dtype: float64

# %% [markdown]
# # Subtask 5

# %%
genre_top10=df.sort_values(by='CVotes1000', ascending=False)

# %%
plt.figure(figsize=[10,8])
sns.barplot(x=genre_top10.index,y=genre_top10.CVotes1000)
plt.title('Top 1000 voters vs genres')
# Out:
# Text(0.5, 1.0, 'Top 1000 voters vs genres')
